# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("titanic_train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %% [markdown]
# Categorical columns:-
# Survived
# Pclass
# Sex
# SibSp
# Parch
# Embarked

# %% [markdown]
# Numerical columns :-
# AGe
# Fare
# PassengerId

# %% [markdown]
# Mixed columns :-
# Cabin
# Ticket
# Name

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 866

# %% [markdown]
# Conclusion:-
#
#     Missing values in Age , cabin , and embarked.
#
#     70% of the data are missing in cabin.
#
#     Few column have in-appropriate data types.

# %% [markdown]
# # Handling missing values

# %%
df.drop(['Cabin' ], axis=1 , inplace = True)

# %%
df['Age'].fillna(df['Age'].mean(),inplace = True)

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].fillna('S',inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.shape
# Out:
# (891, 11)

# %%
df.isnull().sum() # no missing data now
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %% [markdown]
# Changing type of these columns
#
# Survived(Categorical)
#
# Pclass (Categorical)
#
# Sex(Categorical)
#
# Age(int)
#
# Embarked(Categorical)

# %%
df['Embarked'] = df['Embarked'].astype('category')

df['Age'] = df['Age'].astype('int64')

df['Pclass'] = df['Pclass'].astype('category')

df['Sex'] = df['Sex'].astype('category')

df['Survived'] = df['Survived'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    category
# dtypes: category(4), float64(1), int64(4), object(2)
# memory usage: 52.8+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.544332    0.523008    0.381594   32.204208
# std     257.353842   13.013778    1.102743    0.806057   49.693429
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000   29.000000    0.000000    0.000000   14.454200
# 75%     668.500000   35.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # Univariate analysis

# %%
sns.countplot(x= df['Survived'])

death_alive=round(df['Survived'].value_counts())
death_alive
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
death_percent=round((df['Survived'].value_counts().values[0]/891)*100)

print(f"Out of 891 persons : {death_percent}% are dead." )
# Out:
# Out of 891 persons : 62% are dead.

# %%
print((df['Pclass'].value_counts()/891)*100)

sns.countplot(x= df['Pclass']);
# Out:
# Pclass
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: count, dtype: float64

# %%
sns.countplot(x= df['Sex'])
plt.xlabel('Sex')
print((df['Sex'].value_counts()/891)*100)
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: count, dtype: float64

# %%
sns.countplot(x= df['SibSp'])
plt.xlabel('SibSp')
print((df['SibSp'].value_counts()/891)*100)
# Out:
# SibSp
# 0    68.237935
# 1    23.456790
# 2     3.142536
# 4     2.020202
# 3     1.795735
# 8     0.785634
# 5     0.561167
# Name: count, dtype: float64

# %%
sns.countplot(x= df['Embarked'])
plt.xlabel('Embarked')
print((df['Embarked'].value_counts()/891)*100)
# Out:
# Embarked
# S    72.502806
# C    18.855219
# Q     8.641975
# Name: count, dtype: float64

# %%
plt.figure(figsize=(16,9))
sns.displot(df['Age'],kde=True);

# %%
sns.boxplot(df['Age'], orient='h',
                        color='beige',
                    palette='rocket')
plt.title('Box-plot of Age')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# conclusion is :-
#
#
#     Age is normally distributed and we find outliers in Age column .

# %%
print("Person b/w 70 & 75 age: ", df[(df['Age'] >70) & (df['Age']< 75)].shape[0])
print("Person b/w 60 & 70 age: ",df[(df['Age'] >60) & (df['Age']< 70)].shape[0])
print("Person b/w 50 & 60 age: ",df[(df['Age'] >50) & (df['Age']< 60)].shape[0])
print("Person b/w 0 & 1 age: ",df[(df['Age'] >0) & (df['Age']< 1)].shape[0])
# Out:
# Person b/w 70 & 75 age:  3
# Person b/w 60 & 70 age:  15
# Person b/w 50 & 60 age:  38
# Person b/w 0 & 1 age:  0

# %%
# FARE

# %%
sns.displot(df['Fare'],kde=True);

# %%
print(df['Fare'].skew())
print(df['Fare'].kurt())
# Out:
# 4.787316519674893
# 33.39814088089868

# %%
sns.boxplot(df['Fare'],orient='h',palette= 'deep');
plt.xlabel('Fare')
plt.title('Fare Box-plot');

# %%
print("Fare b/w 200$ and 300$ is : ", df[(df['Fare']>200) & (df['Fare']<300)].shape[0])
print("Fare greater than 300$ is : ", df[(df['Fare']>300)].shape[0])
# Out:
# Fare b/w 200$ and 300$ is :  17
# Fare greater than 300$ is :  3

# %% [markdown]
# Conclusion:-
#
#     Highly skewed data, a lot of peope bought cheaper ticket
#     outliers are there in the fare column

# %% [markdown]
# # Multivariate analysis

# %%
# Survived with Pclass
sns.countplot(x= df['Survived'],hue=df['Pclass'])
pd.crosstab(df['Pclass'],df['Survived']).apply(lambda x: round(x/x.sum()*100,1),axis=1)
# Out:
# Survived     0     1
# Pclass
# 1         37.0  63.0
# 2         52.7  47.3
# 3         75.8  24.2

# %%
# Survived with Sex
sns.countplot(x= df['Survived'],hue=df['Sex'])
pd.crosstab(df['Sex'],df['Survived']).apply(lambda x: round(x/x.sum()*100,1),axis =1)
# Out:
# Survived     0     1
# Sex
# female    25.8  74.2
# male      81.1  18.9

# %%
# Survived with Embarked
sns.countplot(x= df['Survived'],hue=df['Embarked'])
pd.crosstab(df['Embarked'],df['Survived']).apply(lambda x :round(x/x.sum()*100,1),axis=1)
# Out:
# Survived     0     1
# Embarked
# C         44.6  55.4
# Q         61.0  39.0
# S         66.1  33.9

# %%
# survived with Age
sns.histplot(df[df['Survived']==0]['Age'],kde=True)
sns.histplot(df[df['Survived']==1]['Age'],kde=True)
pd.crosstab(df['Age'],df['Survived']).apply(lambda x :round(x/x.sum()*100,1),axis=1).head(7)
plt.legend(['blue','orange']);

# %%
# survived with Fare
sns.histplot(df[df['Survived']==0]['Fare'],kde=True)
sns.histplot(df[df['Survived']==1]['Fare'],kde=True)
pd.crosstab(df['Fare'],df['Survived']).apply(lambda x :round(x/x.sum()*100,1),axis=1).head(7)
plt.legend(['blue','orange']);

# %%
sns.pairplot(df,kind='scatter')

# %%
df['Family_size'] = df['Parch'] + df['SibSp']

# %%
df.sample(5)
# Out:
#      PassengerId Survived Pclass                            Name   Sex  Age  \
# 155          156        0      1     Williams, Mr. Charles Duane  male   51
# 143          144        0      3             Burke, Mr. Jeremiah  male   19
# 200          201        0      3  Vande Walle, Mr. Nestor Cyriel  male   28
# 662          663        0      1      Colley, Mr. Edward Pomeroy  male   47
# 152          153        0      3                Meo, Mr. Alfonzo  male   55
#
#      SibSp  Parch      Ticket     Fare Embarked  Family_size
# 155      0      1    PC 17597  61.3792        C            1
# 143      0      0      365222   6.7500        Q            0
# 200      0      0      345770   9.5000        S            0
# 662      0      0        5727  25.5875        S            0
# 152      0      0  A.5. 11206   8.0500        S            0

# %%
def Family_type(number):
    if number ==0 :
        return "Alone"
    elif number >1 or number < 4:
        return "Medium"
    else:
        return "Large"

# %%
df['Family_type'] = df['Family_size'].apply(Family_type)

df.sample(5)
# Out:
#      PassengerId Survived Pclass                           Name     Sex  Age  \
# 655          656        0      2      Hickman, Mr. Leonard Mark    male   24
# 116          117        0      3           Connors, Mr. Patrick    male   70
# 547          548        1      2     Padro y Manent, Mr. Julian    male   29
# 249          250        0      2  Carter, Rev. Ernest Courtenay    male   54
# 797          798        1      3               Osman, Mrs. Mara  female   31
#
#      SibSp  Parch         Ticket     Fare Embarked  Family_size Family_type
# 655      2      0   S.O.C. 14879  73.5000        S            2      Medium
# 116      0      0         370369   7.7500        Q            0       Alone
# 547      0      0  SC/PARIS 2146  13.8625        C            0       Alone
# 249      1      0         244252  26.0000        S            1      Medium
# 797      0      0         349244   8.6833        S            0       Alone

# %%
df.drop(columns= ['SibSp','Parch','Family_size'],inplace = True)

# %%
df.sample(5)
# Out:
#      PassengerId Survived Pclass                                        Name  \
# 885          886        0      3        Rice, Mrs. William (Margaret Norton)
# 715          716        0      3  Soholt, Mr. Peter Andreas Lauritz Andersen
# 644          645        1      3                      Baclini, Miss. Eugenie
# 481          482        0      2            Frost, Mr. Anthony Wood "Archie"
# 38            39        0      3          Vander Planke, Miss. Augusta Maria
#
#         Sex  Age  Ticket     Fare Embarked Family_type
# 885  female   39  382652  29.1250        Q      Medium
# 715    male   19  348124   7.6500        S       Alone
# 644  female    0    2666  19.2583        C      Medium
# 481    male   29  239854   0.0000        S       Alone
# 38   female   18  345764  18.0000        S      Medium

# %%
pd.crosstab(df['Family_type'],df['Survived']).apply(lambda x :round(x/x.sum()*100,1),axis=1).head(5)
# Out:
# Survived        0     1
# Family_type
# Alone        69.6  30.4
# Medium       49.4  50.6

# %% [markdown]
# # Handling outliers

# %%
# Handling outliers in Age i.e. almost normal
df=df[df['Age']<df['Age'].mean() + 3* df['Age'].std()]
df.shape
# Out:
# (884, 10)

# %%
# Handling outliers in fare column
q1,q3=np.percentile(df['Fare'],[25,75])
print('q1 is : ', q1,"\n","q3 is : ", q3)
# Out:
# q1 is :  7.9177
#  q3 is :  31.0

# %%
IQR = q3 - q1
Lower_Fence = q1 -1.5*(IQR)
Upper_Fence = q3 +1.5*(IQR)
print("Lower_Fence is : ", Lower_Fence,"\n","Upper_Fence is : ", Upper_Fence)
# Out:
# Lower_Fence is :  -26.70575
#  Upper_Fence is :  65.62344999999999

# %%
df = df[(df['Fare']>Lower_Fence) &  (df['Fare']<Upper_Fence)]
df.head(5)
# Out:
#    PassengerId Survived Pclass                                          Name  \
# 0            1        0      3                       Braund, Mr. Owen Harris
# 2            3        1      3                        Heikkinen, Miss. Laina
# 3            4        1      1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5        0      3                      Allen, Mr. William Henry
# 5            6        0      3                              Moran, Mr. James
#
#       Sex  Age            Ticket     Fare Embarked Family_type
# 0    male   22         A/5 21171   7.2500        S      Medium
# 2  female   26  STON/O2. 3101282   7.9250        S       Alone
# 3  female   35            113803  53.1000        S      Medium
# 4    male   35            373450   8.0500        S       Alone
# 5    male   29            330877   8.4583        Q       Alone

# %% [markdown]
# # one hot encoding

# %%
df=pd.get_dummies(data=df, columns=['Pclass','Sex','Embarked','Family_type'],
                   drop_first=True).replace([True,False],[1,0])

# %%
df.drop(['Name','Ticket'],axis=1,inplace=True)

# %%
sns.heatmap(df.corr(),cmap='crest', linewidths=1,xticklabels=True,yticklabels=True,
            annot=True,annot_kws={'size': 8})
# Out:
# <Axes: >

# %% [markdown]
# # Conclusion

# %% [markdown]
# Chance of female survival is higher than male survival
#
#
# Travelling in Pclass 3 was deadliest
#
#
# Somehow, people going to C survived more
#
#
# People in the age range of 20 to 40 had a higher chance of not surviving
#
#
# People travelling with smaller familes had a higher chance of surviving
# the accident in comparison to people with large families and travelling alone
